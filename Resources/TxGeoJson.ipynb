# %%
import pandas as pd
from pprint import pprint
import datetime as dt
import json
import os

# %%
#Read in CSV files
txlastStatements = pd.read_csv("tx_deathrow_fulll.csv")
txCoordinates = pd.read_csv("TexasCoordinates.csv")

# %%
txlastStatements.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Execution                553 non-null    int64
#  1   Date of Birth            539 non-null    object
#  2   Date of Offence          536 non-null    object
#  3   Highest Education Level  505 non-null    float64
#  4   Last Name                553 non-null    object
#  5   First Name               553 non-null    object
#  6   TDCJ
# Number              553 non-null    int64
#  7   Age at Execution         553 non-null    int64
#  8   Date Received            539 non-null    object
#  9   Execution Date           553 non-null    object
#  10  Race                     553 non-null    object
#  11  County                   553 non-null    object
#  12  Eye Color                518 non-null    object
#  13  Weight                   511 non-null    float64
# ...

# %%
txCoordinates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   X (Lat)                   254 non-null    float64
#  1   Y (Long)                  254 non-null    float64
#  2   CNTY_NM                   254 non-null    object
#  3   CNTY_NBR                  254 non-null    int64
#  4   FIPS                      254 non-null    int64
#  5   Shape_Leng                254 non-null    float64
#  6   Shape_Area                254 non-null    float64
#  7   County Centroid Location  254 non-null    object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 16.0+ KB

# %%
txCoordinates.rename(columns={'CNTY_NM': 'County'}, inplace=True)
txCoordinates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   X (Lat)                   254 non-null    float64
#  1   Y (Long)                  254 non-null    float64
#  2   County                    254 non-null    object
#  3   CNTY_NBR                  254 non-null    int64
#  4   FIPS                      254 non-null    int64
#  5   Shape_Leng                254 non-null    float64
#  6   Shape_Area                254 non-null    float64
#  7   County Centroid Location  254 non-null    object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 16.0+ KB

# %%
merged_df = pd.merge(txlastStatements, txCoordinates[['County', 'County Centroid Location']], on='County', how='left')
merged_df
merged_df.to_csv('merged_data.csv', index=False)

# %%
merged_df.to_json()
# Out:
# '{"Execution":{"0":553,"1":552,"2":551,"3":550,"4":549,"5":548,"6":547,"7":546,"8":545,"9":544,"10":543,"11":542,"12":541,"13":540,"14":539,"15":538,"16":537,"17":536,"18":535,"19":534,"20":533,"21":532,"22":531,"23":530,"24":529,"25":528,"26":527,"27":526,"28":525,"29":524,"30":523,"31":522,"32":521,"33":520,"34":519,"35":518,"36":517,"37":516,"38":515,"39":514,"40":513,"41":512,"42":511,"43":510,"44":509,"45":508,"46":507,"47":506,"48":505,"49":504,"50":503,"51":502,"52":501,"53":500,"54":499,"55":498,"56":497,"57":496,"58":495,"59":494,"60":493,"61":492,"62":491,"63":490,"64":489,"65":488,"66":487,"67":486,"68":485,"69":484,"70":483,"71":482,"72":481,"73":480,"74":479,"75":478,"76":477,"77":476,"78":475,"79":474,"80":473,"81":472,"82":471,"83":470,"84":469,"85":468,"86":467,"87":466,"88":465,"89":464,"90":463,"91":462,"92":461,"93":460,"94":459,"95":458,"96":457,"97":456,"98":455,"99":454,"100":453,"101":452,"102":451,"103":450,"104":449,"105":448,"106":447,"107":446,"108":445,"10
# ...

# %%
file_path = os.path.join('C:\\Users\\JPHin\\OneDrive\\Documents\\Github2\\Project 3\\Project-3-TeamRavenClaw\\Resources', 'output.json')

# %%
with open(file_path, 'w') as file:
    json.dump(merged_df.to_json(), file)
