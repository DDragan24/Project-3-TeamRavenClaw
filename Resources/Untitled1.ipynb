# %%
import pandas as pd
from pprint import pprint
import datetime as dt
import json
import os

# %%
#Read in Json file
json_file_path = 'txJsonified.json'

# %%
with open(json_file_path, 'r') as file:
    json_data = json.load(file)

# %%
json_data
# Out:
# {'Execution': {'0': 553,
#   '1': 552,
#   '2': 551,
#   '3': 550,
#   '4': 549,
#   '5': 548,
#   '6': 547,
#   '7': 546,
#   '8': 545,
#   '9': 544,
#   '10': 543,
#   '11': 542,
#   '12': 541,
#   '13': 540,
#   '14': 539,
#   '15': 538,
#   '16': 537,
#   '17': 536,
#   '18': 535,
#   '19': 534,
#   '20': 533,
#   '21': 532,
#   '22': 531,
#   '23': 530,
#   '24': 529,
#   '25': 528,
#   '26': 527,
#   '27': 526,
#   '28': 525,
#   '29': 524,
#   '30': 523,
#   '31': 522,
#   '32': 521,
#   '33': 520,
#   '34': 519,
#   '35': 518,
#   '36': 517,
#   '37': 516,
#   '38': 515,
#   '39': 514,
#   '40': 513,
#   '41': 512,
#   '42': 511,
#   '43': 510,
#   '44': 509,
#   '45': 508,
#   '46': 507,
#   '47': 506,
#   '48': 505,
#   '49': 504,
#   '50': 503,
#   '51': 502,
#   '52': 501,
#   '53': 500,
#   '54': 499,
#   '55': 498,
#   '56': 497,
#   '57': 496,
#   '58': 495,
#   '59': 494,
#   '60': 493,
#   '61': 492,
#   '62': 491,
#   '63': 490,
#   '64': 489,
#   '65': 488,
# ...

# %%
def get_info_by_number('2'):
    return json_data.get(str('2'))
# Out:
#   Cell In[12], line 1
#     def get_info_by_number('2'):
#                            ^
# SyntaxError: invalid syntax
