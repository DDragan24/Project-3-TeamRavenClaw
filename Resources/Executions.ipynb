# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
# %matplotlib inLine
from scipy.stats import linregress

# %%
executionDF = pd.read_csv("DPIC Execution Database - U.S. Executions.csv")

# %%
columns = executionDF.columns.tolist()
print(columns)
# Out:
# ['Foreign National', 'Number of White Male Victims', 'Juvenile', 'First Name', 'Last Name', 'Middle Name(s)', 'Suffix', 'Race', 'Sex', 'Region', 'Country', 'State', 'Execution Date', 'Number of Victims', 'Number of Black Male Victims', 'Number of Latino Male Victims', 'Number of Asian Male Victims', 'Number of Native American Male Victims', 'Number of Other Race Male Victims', 'Number of White Female Victims', 'Number of Black Female Victims', 'Number of Latino Female Victims', 'Number of Asian Female Victims', 'Number of American Indian or Alaska Native Female Victims', 'Number of Other Race Female Victims', 'Victim(s) Race(s)', 'Race of Victims (Multiple races including white)']

# %%
executionDF.head()
# Out:
#   Foreign National  Number of White Male Victims Juvenile First Name  \
# 0               No                             1       no       Gary
# 1               No                             1       no       John
# 2               No                             1       no      Jesse
# 3               No                             2       no     Steven
# 4               No                             1       no      Frank
#
#     Last Name Middle Name(s) Suffix   Race   Sex   Region  ...  \
# 0     Gilmore           Mark    NaN  White  Male     West  ...
# 1  Spenkelink            NaN    NaN  White  Male    South  ...
# 2      Bishop            NaN    NaN  White  Male     West  ...
# 3        Judy            NaN    NaN  White  Male  Midwest  ...
# 4     Coppola            NaN    NaN  White  Male    South  ...
#
#   Number of Native American Male Victims Number of Other Race Male Victims  \
# 0                                      0                                 0
# ...

# %%
index_to_delete = newExecutionDF[(executionDF['First Name'] == 'Richard') & (df['Last Name'] == 'Fairchild')].index
# Out:
# C:\Users\JPHin\AppData\Local\Temp\ipykernel_54476\3167997233.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   index_to_delete = newExecutionDF[(executionDF['First Name'] == 'Richard') & (df['Last Name'] == 'Fairchild')].index

# %%
index_to_delete = newExecutionDF[(executionDF['First Name'] == 'Jemaine') &(executionDF['Last Name'] == 'Cannon')].index

# Delete the row with the specified name
executionDF.drop(index_to_delete, inplace=True)

# Display the updated DataFrame
print(executionDF)
# Out:
#      Foreign National  Number of White Male Victims Juvenile First Name  \
# 0                  No                             1       no       Gary
# 1                  No                             1       no       John
# 2                  No                             1       no      Jesse
# 3                  No                             2       no     Steven
# 4                  No                             1       no      Frank
# ...               ...                           ...      ...        ...
# 1586               no                             1       no      Brian
# 1587               no                             1       no      Jamie
# 1588               no                             1       no      David
# 1589               no                             0       no     Ramiro
# 1590               no                             0       no    Richard
#
#        Last Name Middle Name(s) Suffix    Race   Sex   Region  ...  \
# ...

# %%
newExecutionDF = executionDF.drop(columns=["Middle Name(s)", "Suffix"])
newExecutionDF.head()
# Out:
#   Foreign National  Number of White Male Victims Juvenile First Name  \
# 0               No                             1       no       Gary
# 1               No                             1       no       John
# 2               No                             1       no      Jesse
# 3               No                             2       no     Steven
# 4               No                             1       no      Frank
#
#     Last Name   Race   Sex   Region        Country     State  ...  \
# 0     Gilmore  White  Male     West  United States      Utah  ...
# 1  Spenkelink  White  Male    South  United States   Florida  ...
# 2      Bishop  White  Male     West  United States    Nevada  ...
# 3        Judy  White  Male  Midwest  United States   Indiana  ...
# 4     Coppola  White  Male    South  United States  Virginia  ...
#
#   Number of Native American Male Victims  Number of Other Race Male Victims  \
# ...

# %%
sexCount = newExecutionDF.value_counts('Sex')
sexCount
# Out:
# Sex
# Male      1571
# Female      18
# Male         1
# Name: count, dtype: int64

# %%
#Pie chart for race of accused
raceCounts = newExecutionDF['Race'].value_counts()
raceCounts
# Out:
# Race
# White                               885
# Black                               540
# Latinx                              132
# American Indian or Alaska Native     21
# Asian                                 7
# Other Race                            3
# Latino                                2
# Name: count, dtype: int64

# %%
#pie chart for race of victims

# %%
#bar chart for state
